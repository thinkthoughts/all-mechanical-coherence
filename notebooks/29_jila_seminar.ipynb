# %% [markdown]
# # JILA Seminar Notes
#
# Collect seminar questions, answers, and follow-up directions.
#
# Repository: `all-mechanical-coherence`

# %%
from pathlib import Path
import yaml

ROOT = Path.cwd()
if not (ROOT / "paper.yaml").exists():
    ROOT = ROOT.parent

with open(ROOT / "paper.yaml", "r", encoding="utf-8") as f:
    paper = yaml.safe_load(f)

paper["paper"]["title"], paper["paper"]["arxiv"]

# %% [markdown]
# ## Notes
#
# - Add source excerpts, equations, diagrams, or seminar notes here.
# - Keep results reproducible and exportable into `reports/`.
