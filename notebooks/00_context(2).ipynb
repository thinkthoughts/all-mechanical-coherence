# %% [markdown]
# # 00 — Context
#
# This notebook initializes the `all-mechanical-coherence` repository.

# %%
from pathlib import Path
import sys

ROOT = Path.cwd().parent
SRC = ROOT / 'src'

# %%
import yaml

paper_yaml = ROOT / 'paper.yaml'

# %% [markdown]
# ## Paper metadata

# %%
paper = data['paper']
print(paper['title'])

# %% [markdown]
# ## Core claim

# %%
print(data['core_claim'])

# %% [markdown]
# ## Toward phonon-mediated quantum gates
#
# Track how all-mechanical coherence protection may support future phonon-mediated quantum gates.
